# %% [markdown]
# ## Question 1

# %%
number1 = float(input("enter number 1:"))
number2 = float(input("enter number 2:"))
if number1 < 0:
    number1 = -number1
if number2 < 0:
    number2 = - number2
print("abs number is :",number1+number2)
# Out:
# abs number is : 8.0

# %% [markdown]
# ## Question 2

# %%
number1 = float(input("enter number 1:"))
number2 = float(input("enter number 2:"))
number3 = float(input("enter number 3:"))



if number1<=number2<=number3:
    print(number2)

if number2<=number3<=number1:
    print(number3)
if number3<=number1<=number2:
    print(number1)

if number1>=number2>=number3:
    print(number2)

if number2>=number3>=number1:
    print(number3)
if number3>=number1>=number2:
    print(number1)
# Out:
# 2.0
