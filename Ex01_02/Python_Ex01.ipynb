# %% [markdown]
# ## Question 1

# %%
# variable
num1 = 12.6
num2 = "050"
num3 = "20."
student_num = "s98234"
flag = True
#type
print(type(num1))
print(type(num2))
print(type(num3))
print(type(student_num))
print(type(flag))
#change type
print("Change to integer:")
num1 = int(num1)
num2 = int(num2)
num3 = int(float(num3))
#student_num = int(student_num)
flag = int(flag)
print(type(num1))
print(type(num2))
print(type(num3))
print(type(student_num),"not change to integer")
print(type(flag))
print("Change to float:")
num1 = float(num1)
num2 = float(num2)
num3 = float(num3)
#student_num = float(student_num)
flag = float(flag)
print(type(num1))
print(type(num2))
print(type(num3))
print(type(student_num),"not change to float")
print(type(flag))

# section 2
print("section 2")
num1 = -20
num2 = 00
flag = "False"
#type
print(type(num1))
print(type(num2))
print(type(flag))
print("change to bool:")
num1 = bool(num1)
num2 = bool(num2)
flag = bool(flag)
print(type(num1))
print(type(num2))
print(type(flag))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# Change to integer:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'> not change to integer
# <class 'int'>
# Change to float:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'> not change to float
# <class 'float'>
# section 2
# <class 'int'>
# <class 'int'>
# <class 'str'>
# change to bool:
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ## Question 2

# %%
num1 = 20
num2 = 19.
num3 = "18.5"
num1 = float(num1)
num2 = float(num2)
num3 = float(num3)
average = (num1 + num2 + num3 )/3
print("average is equal ",average)
# Out:
# average is equal  19.166666666666668

# %% [markdown]
# ## Question 3

# %%
num1 = 10
num2 = 20
if num1>num2:
    print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# ## Question 4

# %%
length = float(input("length"))
width = float(input("width"))


print("area:",length * width)
print("perimeter:",2*(length + width))
# Out:
# area: 6.0
# perimeter: 10.0

# %% [markdown]
# ## Question 5

# %%
radius = float(input("enter radius:"))
Diameter = radius * 2
x = Diameter * Diameter
y = 3.14 * radius * radius
print(" colored part:",x - y)
# Out:
#  colored part: 3.4399999999999995

# %% [markdown]
# ## Question 6

# %%
num1 = num2 = num3 = 200
print(num1,end=" ")
print(num2,end=" ")
print(num3)

num1 , num2 , num3 = 10, 20, 145
print(num1,end=" ")
print(num2,end=" ")
print(num3)
num1 , num2 , num3 = 30, 100 , 5
print("erroe is fixed because num3 not define:",num1,end=" ")
print(num2,end=" ")
print(num3)
# Out:
# 200 200 200
# 10 20 145
# erroe is fixed because num3 not define: 30 100 5
